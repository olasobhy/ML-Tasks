# %%
import pandas as pd  
from apyori import apriori

# %%
df2 = pd.read_csv('GroceryStoreDataSet.csv' , names=['product'] , header = None )

# %%
df2.head()
# Out:
#                          product
# 0             MILK,BREAD,BISCUIT
# 1  BREAD,MILK,BISCUIT,CORNFLAKES
# 2            BREAD,TEA,BOURNVITA
# 3           JAM,MAGGI,BREAD,MILK
# 4              MAGGI,TEA,BISCUIT

# %%
store=list(df2['product'].apply(lambda x: x.split(",")))
store
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COCK'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
store[0]
# Out:
# ['MILK', 'BREAD', 'BISCUIT']

# %%
records = []  
for i in range(0, len(store)):  
     for j in range(len(store[i])):
        records.append(store[i][j])

# %%
records
# Out:
# ['MILK',
#  'BREAD',
#  'BISCUIT',
#  'BREAD',
#  'MILK',
#  'BISCUIT',
#  'CORNFLAKES',
#  'BREAD',
#  'TEA',
#  'BOURNVITA',
#  'JAM',
#  'MAGGI',
#  'BREAD',
#  'MILK',
#  'MAGGI',
#  'TEA',
#  'BISCUIT',
#  'BREAD',
#  'TEA',
#  'BOURNVITA',
#  'MAGGI',
#  'TEA',
#  'CORNFLAKES',
#  'MAGGI',
#  'BREAD',
#  'TEA',
#  'BISCUIT',
#  'JAM',
#  'MAGGI',
#  'BREAD',
#  'TEA',
#  'BREAD',
#  'MILK',
#  'COFFEE',
#  'COCK',
#  'BISCUIT',
#  'CORNFLAKES',
#  'COFFEE',
#  'COCK',
#  'BISCUIT',
#  'CORNFLAKES',
#  'COFFEE',
#  'SUGER',
#  'BOURNVITA',
#  'BREAD',
#  'COFFEE',
#  'COCK',
#  'BREAD',
#  'SUGER',
#  'BISCUIT',
#  'COFFEE',
#  'SUGER',
#  'CORNFLAKES',
#  'BREAD',
#  'SUGER',
#  'BOURNVITA',
#  'BREAD',
#  'COFFEE',
#  'SUGER',
#  'BREAD',
#  'COFFEE',
#  'SUGER',
#  'TEA',
#  'MILK',
#  'COFFEE',
#  'CORNFLAKES']

# %%
association_rules = apriori(store, min_support=0.1, min_confidence=0.2, 
                            in_lift=3, min_length=2)  
association_results = list(association_rules)  


for item in association_results :

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    if len(items)>=2 :
         print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Support: 0.35
# Confidence: 0.35
# Lift: 1.0
# ...
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ...
# Support: 0.65
# Confidence: 0.65
# Lift: 1.0
# ...
# Support: 0.4
# Confidence: 0.4
# Lift: 1.0
# ...
# Support: 0.3
# Confidence: 0.3
# Lift: 1.0
# ...
# Support: 0.25
# Confidence: 0.25
# Lift: 1.0
# ...
# Support: 0.25
# Confidence: 0.25
# Lift: 1.0
# ...
# Support: 0.3
# Confidence: 0.3
# Lift: 1.0
# ...
# Support: 0.35
# Confidence: 0.35
# Lift: 1.0
# ...
# Rule: BISCUIT -> BREAD
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ...
# Rule: COCK -> BISCUIT
# Support: 0.1
# Confidence: 0.28571428571428575
# Lift: 1.904761904761905
# ...
# Rule: COFFEE -> BISCUIT
# Support: 0.1
# Confidence: 0.28571428571428575
# Lift: 0.7142857142857143
# ...
# Rule: CORNFLAKES -> BISCUIT
# Support: 0.15
# Confidence: 0.4285714285714286
# Lift: 1.4285714285714288
# ...
# Rule: MAGGI -> BISCUIT
# Support: 0.1
# Confidence: 0.28571428571428575
# Lift: 1.142857142857143
# ...
# Rule: MILK -> BISCUIT
# Support: 0.1
# Confidence: 0.28571428571428575
# Lift: 1.142857142857143
# ...

# %%
len(association_results)
# Out:
# 44

# %%
item[0]
# Out:
# frozenset({'MILK', 'TEA'})
